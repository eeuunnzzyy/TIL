# %%
# 네이버 뉴스 자율주행 크롤링

# %%
import requests
from pandas import DataFrame
from bs4 import BeautifulSoup
import re
from datetime import datetime
import os

# %%
date = str(datetime.now())
date = date[:date.rfind(':')].replace('','_')
date = date.replace(':','시') + '분'

# %%
# 인풋 생성
query = input('검색 키워드를 입력하세요 : ')
query = query.replace(' ', '+')

news_num = int(input('총 필요한 뉴스기사 수를 입력해주세요(숫자만 입력) : '))
# Out:
# 검색 키워드를 입력하세요 : 자율주행
# 총 필요한 뉴스기사 수를 입력해주세요(숫자만 입력) : 6

# %%
# 키워드 = '자율주행'
# = f'https://m.search.naver.com/search.naver?where=m_news&sm=mtb_jum&query={키워드}'
# print(news_url)
#https://m.search.naver.com/search.naver?sm=mtp_hty.top&where=m&query=%EC%9E%90%EC%9C%A8%EC%A3%BC%ED%96%89

# %%
news_url = 'https://search.naver.com/search.naver?where=m_news&sm=mtb_jum&query={}'

req = requests.get(news_url.format(query)) # html 코드 받아오기 <Response [200]>
soup = BeautifulSoup(req.text, 'html.parser') # 받은 코드로 파싱

# %%
soup
# Out:
# <!DOCTYPE html>
#  <html lang="ko"> <head> <meta charset="utf-8"/> <meta content="always" name="referrer"/> <meta content="telephone=no,address=no,email=no" name="format-detection"/> <meta content="width=device-width,initial-scale=1.0,maximum-scale=2.0" name="viewport"/> <meta content="자율주행 : 네이버 통합검색" property="og:title"> <meta content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png" property="og:image"/> <meta content="'자율주행'의 네이버 통합검색 결과입니다." property="og:description"/> <meta content="'자율주행'의 네이버 통합검색 결과입니다." lang="ko" name="description"/> <title>자율주행 : 네이버 통합검색</title> <link href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_191118_pc.ico" rel="shortcut icon"/> <link href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" rel="search" title="Naver" type="application/opensearchdescription+xml"><link href="https://ssl.pstatic.net/sstatic/search/pc/css/search1_220602.css" rel="stylesheet" type="text/css"/> <link href="https://ssl.pstatic.net/sstatic/search/pc/css/search2_220519a.css" rel="stylesheet" type="text/css"/> <link href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_220526.css" rel="stylesheet" type="text/css"/><script type="text/javascript"> if (!String.prototype.trim) { String.prototype.trim = function () { return this.replace(/^[\s\uFEFF\xA0]+|[\s\uFEFF\xA0]+$/g, ''); }; } if (!Array.prototype.indexOf) { Array.prototype.indexOf = function(searchElement, fromIndex) { var k; if (this == null) { throw new TypeError('"this" is null or not defined'); } var o = Object(this); var len = o.length >>> 0; if (len === 0) { return -1; } var n = fromIndex | 0; if (n >= len) { return -1; } k = Math.max(n >= 0 ? n : len - Math.abs(n), 0); while (k < len) { if (k in o && o[k] === searchElement) { return k; } k++; } return -1; }; } if (!Array.prototype.filter) { Array.prototype.filter = function(func, thisArg) { 'use strict'; if (!((typeof func === 'Function' || typeof func === 'function') && this)) throw new TypeError(); var len = this.length >>> 0, res = new Array(len), t = this, c = 0, i = -1; var kValue; if (thisArg === undefined) { while (++i !== len) { if (i in this) { kValue = t[i]; if (func(t[i], i, t)) { res[c++] = kValue; } } } } else { while (++i !== len) { if (i in this) { kValue = t[i]; if (func.call(thisArg, t[i], i, t)) { res[c++] = kValue; } } } } res.length = c; return res; }; } if (typeof(encodeURIComponent) != "function") { encodeURIComponent = function (s) { function toHex (n) { var hexchars = "0123456789ABCDEF" ; return "%%" + hexchars.charAt(n>>4) + hexchars.charAt(n&0xF) ; } var es = "" ; for (var i = 0; i < s.length;) { var c = s.charCodeAt(i++) ; if ((c&0xF800) == 0xD800) { var sc = s.charCodeAt(i++) ; c = ((c-0xD800)<<10) + (sc-0xDC00) + 0x10000 ; } if (!(c&~0x7F)) { if ((c>=65&&c<=90) || (c>=97&&c<=122) || (c>=48&&c<=57) || (c>=45&&c<=46) || c==95 || c==33 || c==126 || (c>=39&&c<=42)) es += String.fromCharCode(c) ; else es += toHex(c) ; } else if (!(c&~0x7FF)) es += toHex(0xC0+(c>>6)) + toHex(c&0x3F) ; else if (!(c&~0xFFFF)) es += toHex(0xE0+(c>>12)) + toHex(0x80+(c>>6&0x3F)) + toHex(0x80+(c&0x3F)) ; else es += toHex(0xF0+(c>>18)) + toHex(0x80+(c>>12&0x3F)) + toHex(0x80+(c>>6&0x3F)) + toHex(0x80+(c&0x3F)) ; } return es ; } } naver = window.naver || {}; naver.search = naver.search || {}; naver.search.abt_param = ""; var g_D = 0 ; naver.search.error = (function () { var errorList = Array() ; return { add : function (s) { errorList.push(s) ; }, clear : function () { delete errorList ; }, get : function (s) { return errorList ; }, getString : function (d) { if (typeof d === 'undefined') d = '|' ; return errorList.join(d) ; } } })(); naver.search.cookie = (function () { return { set : function (key, value, expire, domain) { var cookie = key + "=" + escape(value); if (typeof expire !== 'undefined') { if (expire instanceof Date) { cookie = cookie + "; expires=" + expire.toUTCString(); } else { var exdate = new Date((new Date()).getTime() + expire*1000); cookie = cookie + " ...
# <script type="text/javascript">
#     if (typeof NAVER === "undefined") {
#       NAVER = {};
#     }
#     if (typeof NAVER.SEARCH_AD === "undefined") {
#       NAVER.SEARCH_AD = {};
#     }
#     NAVER.SEARCH_AD.showTooltip = function (element) {
#       var parentElement = $Element(element).parent();
#       var timerAttribute = parentElement.attr("data-timer");
#       if (timerAttribute) {
#         clearTimeout(timerAttribute);
#         parentElement.attr("data-timer", "");
#       }
#       var tooltipElement = $Element(parentElement.query("._tooltip"));
#       tooltipElement.css("display", "inline");
#     };
#     NAVER.SEARCH_AD.hideTooltip = function (element) {
#       var parentElement = $Element(element).parent();
#       if (!parentElement.attr("data-timer")) {
#         var timer = setTimeout(function () {
#           var tooltipElement = $Element(parentElement.query("._tooltip"));
#           tooltipElement.css("display", "none");
#         }, 100);
#         parentElement.attr("data-timer", timer);
#       }
#     };
#
#     var _elAdIndLayerPl = null;
#     var _elAdIndLayerTimePl;
#     var _elDscNcautionPl = null;
#
#     function adInfoShowPl(el) {
#       if (_elAdIndLayerPl) {
#         adInfoHidePl();
#         return false;
#       } else {
#         if (!_elDscNcautionPl) {
#           _elDscNcautionPl = $Element(el).parent();
#         }
#         _elDscNcautionPl._element.style.zIndex = 121;
#         _elAdIndLayerPl = $Element(el).next();
#         _elAdIndLayerPl.show();
#         _elAdIndLayerTimePl = (new Date()).getTime();
#         return true;
#       }
#     }
#
#     function adInfoHidePl() {
#       if (_elAdIndLayerPl) {
#         if (_elDscNcautionPl) {
#           _elDscNcautionPl._element.style.zIndex = 0;
#         }
#         _elAdIndLayerPl.hide();
#         _elAdIndLayerPl = null;
#       }
#     }
#
#     function adInfoHideClickEventHandlerPl(e) {
#       if (_elAdIndLayerTimePl + 200 < (new Date()).getTime()) adInfoHidePl();
#     }
#
#     document.body[window.addEventListener ? 'addEventListener' : 'attachEvent'](window.addEventListener ? "click" : "onclick", adInfoHideClickEventHandlerPl, false);
#   </script>
# <link href="https://ssl.pstatic.net/adimg3.search/imp/nx/power/pc/220609/css/nx_powerlink.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/sstatic/search/local/css/maps_openapi_https_150716.css" rel="stylesheet" type="text/css"/>
# <div class="ad_section section _pl_section bg_type_v2">
# <div class="section_head nx_power"><h2>파워링크</h2>
# <div class="dsc_ncaution">
# <span><em class="dsc_ncaution_quotation">‘</em><strong class="dsc_ncaution_keyword">자율주행</strong><em class="dsc_ncaution_quotation">’</em></span>
# <span class="dsc_ncaution_text">관련 광고입니다.</span>
# <a class="ico_ad_dsc" href="javascript:void(0);" onclick="if(adInfoShowPl(this)) goOtherCR(this, 'a=pwl_nop.adset&amp;r=0&amp;i=pwl_nopadset&amp;u='+urlencode(this.href));" title="이 광고가 표시된 이유">이 광고가 표시된 이유</a>
# <div class="ly_ad_dsc" onclick="adInfoHidePl();" style="display:none">
# <p>광고 노출기준은 검색어에 대한 연관성과 광고주의 입찰가이며,
#             이미지 등 추가 링크는 등록한 경우에만 기준에 따라 노출됩니다. <a class="link_help" href="https://saedu.naver.com/help/faq/ncc/view.nhn?faqSeq=704">도움말</a></p>
# <button class="bt_ad_clse" type="button">안내 레이어 닫기</button>
# </div>
# </div>
# <a class="go_register space" href="//saedu.naver.com/adbiz/searchad/intro.nhn" onclick="return goOtherCR(this, 'a=pwl_nop.registration&amp;r=0&amp;i=pwl_nopregistration&amp;u='+urlencode(this.href));" target="_blank">등록 안내</a>
# </div>
# <div class="nad_area" id="power_link_body" impression-event-url="https://event.impression-neo.naver.com/api/v1/events/naver_search/impression?x=...">
# <ul class="lst_type">
# <li class="lst type_more type_subtitle ext_link" num="0" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="inner">
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=Br9dKLkfCPGbp12CcEoRGP///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=pwl_nop.tit&amp;r=1&amp;i=nad-a001-01-000000184698179&amp;d=' + urlencode('https://www.hlklemove.com') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <div class="lnk_tit">HL클레무브</div>
# <div class="sub_tit">자동차를 넘은 모든 모빌리티</div>
# </a>
# <div class="url_area">
# <span class="ico_ad_mark">광고</span>
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=Br9dKLkfCPGbp12CcEoRGP///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=1&amp;i=nad-a001-01-000000184698179&amp;d='+urlencode('https://www.hlklemove.com')+'&amp;u='+urlencode(this.href));" target="_blank">www.hlklemove.com</a>
# </div>
# <div class="ad_dsc"><p class="ad_dsc_inner">
#               가장 편안한 이동이 가장 안전한 순간이 될 수 있도록
#
#             </p></div>
# <ul class="lst_link">
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=jXdpOXhQ+CqXH21jrw4DyP///w==..." onclick="return goOtherCR(this,'a=pwl_nop.sublink1&amp;r=1&amp;i=nad-a001-01-000000184698179&amp;d='+urlencode('https://www.hlklemove.com')+'&amp;u='+urlencode(this.href));" target="_blank">사업분야</a>
# </li>
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=BSFYWcydTkgtw2lrv7vS5////w==..." onclick="return goOtherCR(this,'a=pwl_nop.sublink2&amp;r=1&amp;i=nad-a001-01-000000184698179&amp;d='+urlencode('https://www.hlklemove.com')+'&amp;u='+urlencode(this.href));" target="_blank">인재채용</a>
# </li>
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=UoSurzkRSSkPlxGNMxp/4f///w==..." onclick="return goOtherCR(this,'a=pwl_nop.sublink3&amp;r=1&amp;i=nad-a001-01-000000184698179&amp;d='+urlencode('https://www.hlklemove.com')+'&amp;u='+urlencode(this.href));" target="_blank">고객센터</a>
# </li>
# </ul>
# </div>
# </li>
# <li class="lst type_more type_subtitle type_img" num="1" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <a class="lnk_thumb" href="https://adcr.naver.com/adcr?x=kSn13UXvRN0D+XHuWr19Xv///w==..." onclick="return goOtherCR(this,'a=pwl_nop.image&amp;r=2&amp;i=nad-a001-01-000000162527548&amp;d='+urlencode('https://yujinrobot.com/')+'&amp;u='+urlencode(this.href));" target="_blank">
# <img alt="링크이미지" class="img_thumb" height="70" src="https://searchad-phinf.pstatic.net/MjAyMTEyMDJfMTY1/MDAxNjM4NDI0ODQyMDIz.TJcIqOD68HJgDQd0sIK1-B9ks3ldtTcCRBaUVxK-O9Ig.ig4prqPiMstjgCUYU9lOmLPJ6EU2MLEB-pdwe6v6OXUg.JPEG/1867851-dc33aad7-1b8d-47a6-8d86-d4df237e26b9.jpg?type=f120_120" width="70"/>
# </a>
# <div class="inner">
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=bjhItfiptc7lYz6ZjBaLef///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=pwl_nop.tit&amp;r=2&amp;i=nad-a001-01-000000162527548&amp;d=' + urlencode('https://yujinrobot.com/') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <div class="lnk_tit">자율주행 로봇 (주)유진로봇</div>
# <div class="sub_tit">GoCart250 출시</div>
# </a>
# <div class="url_area">
# <span class="ico_ad_mark">광고</span>
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=bjhItfiptc7lYz6ZjBaLef///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=2&amp;i=nad-a001-01-000000162527548&amp;d='+urlencode('https://yujinrobot.com/')+'&amp;u='+urlencode(this.href));" target="_blank">yujinrobot.com/</a>
# </div>
# <div class="ad_dsc"><p class="ad_dsc_inner">
#               국제표준 안전인증 ISO 13482 획득! <strong class="hl">자율주행</strong> 로봇 토탈 솔루션 제공
#
#             </p></div>
# </div>
# </li>
# <li class="lst type_more type_subtitle ext_link type_img" num="2" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <a class="lnk_thumb" href="https://adcr.naver.com/adcr?x=YZAWPnmlH3XxC6m0KK7o1////w==..." onclick="return goOtherCR(this,'a=pwl_nop.image&amp;r=3&amp;i=nad-a001-01-000000170010474&amp;d='+urlencode('http://www.myrobotsolution.com')+'&amp;u='+urlencode(this.href));" target="_blank">
# <img alt="링크이미지" class="img_thumb" height="70" src="https://searchad-phinf.pstatic.net/MjAyMjAyMDhfMTcg/MDAxNjQ0MjkyNTQzODE0.dwvUTmyIRj1MDgrB2MUlKvR8XjLR50WSLLw7zMddpWwg.m5yEfZowHAGS26s_ag9WOHmLLcMYR4aeUeuEKd3TGSUg.PNG/2072810-22605578-bfb6-4d76-b972-fe5b01046aca.PNG?type=f120_120" width="70"/>
# </a>
# <div class="inner">
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=AdCheA1cEvN0efU5iSqgwv///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=pwl_nop.tit&amp;r=3&amp;i=nad-a001-01-000000170010474&amp;d=' + urlencode('http://www.myrobotsolution.com') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <div class="lnk_tit">물류 자동화 전문 마로솔</div>
# <div class="sub_tit">물류로봇 전문가 상담 무료</div>
# </a>
# <div class="url_area">
# <span class="ico_ad_mark">광고</span>
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=AdCheA1cEvN0efU5iSqgwv///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=3&amp;i=nad-a001-01-000000170010474&amp;d='+urlencode('http://www.myrobotsolution.com')+'&amp;u='+urlencode(this.href));" target="_blank">www.myrobotsolution.com</a>
# </div>
# <div class="ad_dsc"><p class="ad_dsc_inner">
#               빠른도입이 필요하세요? 일일히 견적 받지 말고 마로솔로 한 번에 해결!
#
#             </p></div>
# <ul class="lst_link">
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=7c2klDfEz8QvlK4N58pXkv///w==..." onclick="return goOtherCR(this,'a=pwl_nop.sublink1&amp;r=3&amp;i=nad-a001-01-000000170010474&amp;d='+urlencode('http://www.myrobotsolution.com')+'&amp;u='+urlencode(this.href));" target="_blank">서비스 소개</a>
# </li>
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=T0PmeehaiT8KHpdiLXfKE////w==..." onclick="return goOtherCR(this,'a=pwl_nop.sublink2&amp;r=3&amp;i=nad-a001-01-000000170010474&amp;d='+urlencode('http://www.myrobotsolution.com')+'&amp;u='+urlencode(this.href));" target="_blank">스토어</a>
# </li>
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=yFHcs+5NIEKYYjTjFAtJUP///w==..." onclick="return goOtherCR(this,'a=pwl_nop.sublink3&amp;r=3&amp;i=nad-a001-01-000000170010474&amp;d='+urlencode('http://www.myrobotsolution.com')+'&amp;u='+urlencode(this.href));" target="_blank">도입사례</a>
# </li>
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=IzunzlLhr+TZowsqAAobWP///w==..." onclick="return goOtherCR(this,'a=pwl_nop.sublink4&amp;r=3&amp;i=nad-a001-01-000000170010474&amp;d='+urlencode('http://www.myrobotsolution.com')+'&amp;u='+urlencode(this.href));" target="_blank">문의하기</a>
# </li>
# </ul>
# </div>
# </li>
# <li class="lst type_more" num="3" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="inner">
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=+zIz/3pI/B4fZsuwrUf03f///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=pwl_nop.tit&amp;r=4&amp;i=nad-a001-01-000000124973970&amp;d=' + urlencode('http://www.nxp.com') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <div class="lnk_tit">NXP반도체 공식웹사이트</div>
# </a>
# <div class="url_area">
# <span class="ico_ad_mark">광고</span>
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=+zIz/3pI/B4fZsuwrUf03f///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=4&amp;i=nad-a001-01-000000124973970&amp;d='+urlencode('http://www.nxp.com')+'&amp;u='+urlencode(this.href));" target="_blank">www.nxp.com</a>
# </div>
# <div class="ad_dsc"><p class="ad_dsc_inner">
#                자동차 산업 IoT 모바일 통신 인프라 시장 혁신 보안 연결 솔루션 선도 기업
#
#             </p></div>
# </div>
# </li>
# <li class="lst type_more type_subtitle type_img" num="4" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <a class="lnk_thumb" href="https://adcr.naver.com/adcr?x=g/MoeD1s1JrDwh/zqHhCCv///w==..." onclick="return goOtherCR(this,'a=pwl_nop.image&amp;r=5&amp;i=nad-a001-01-000000159621755&amp;d='+urlencode('http://www.rotal.kr/')+'&amp;u='+urlencode(this.href));" target="_blank">
# <img alt="링크이미지" class="img_thumb" height="70" src="https://searchad-phinf.pstatic.net/MjAyM
kr') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <div class="lnk_tit">노바텔한국 인성인터내쇼날</div>
# </a>
# <div class="url_area">
# <span class="ico_ad_mark">광고</span>
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=R//GFhjcNf/HwHopeYI9yP///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=8&amp;i=nad-a001-01-000000039173401&amp;d='+urlencode('http://www.insungsys.kr')+'&amp;u='+urlencode(this.href));" target="_blank">www.insungsys.kr</a>
# </div>
# <div class="ad_dsc"><p class="ad_dsc_inner">
# <strong class="hl">자율주행</strong>, 노바텔한국대리점, 카카오, 삼성,현대자동차,LG전자, SK 기술지원업체
#
#             </p></div>
# </div>
# </li>
# <li class="lst" num="8" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="inner">
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=mbzfQ4w1MGd9Gkwv0CF9PP///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=pwl_nop.tit&amp;r=9&amp;i=nad-a001-01-000000154196237&amp;d=' + urlencode('http://fastcampus.co.kr') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <div class="lnk_tit">지금 자율주행 필수 지식</div>
# </a>
# <div class="url_area">
# <span class="ico_ad_mark">광고</span>
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=mbzfQ4w1MGd9Gkwv0CF9PP///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=9&amp;i=nad-a001-01-000000154196237&amp;d='+urlencode('http://fastcampus.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">fastcampus.co.kr</a>
# </div>
# <div class="ad_dsc"><p class="ad_dsc_inner">
#               정확한 오브젝트 트래킹을 위해 필요한 <strong class="hl">자율주행</strong> 센서퓨전 기술을 배워보세요.
#
#             </p></div>
# </div>
# </li>
# <li class="lst" num="9" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="inner">
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=HIOl+RRJZgEETQ5EBV947P///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=pwl_nop.tit&amp;r=10&amp;i=nad-a001-01-000000061000934&amp;d=' + urlencode('http://www.wisesystem.co.kr') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <div class="lnk_tit">와이즈시스템 자율주행</div>
# </a>
# <div class="url_area">
# <span class="ico_ad_mark">광고</span>
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=HIOl+RRJZgEETQ5EBV947P///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=10&amp;i=nad-a001-01-000000061000934&amp;d='+urlencode('http://www.wisesystem.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">www.wisesystem.co.kr</a>
# </div>
# <div class="ad_dsc"><p class="ad_dsc_inner">
# <strong class="hl">자율주행</strong>에 필요한 정밀항법장치와 테스트 솔루션
#
#             </p></div>
# </div>
# </li>
# </ul>
# <div class="section_more">
# <a class="go_site" href="https://ad.search.naver.com/search.naver?where=ad&amp;query=%EC%9E%90%EC%9C%A8%EC%A3%BC%ED%96%89&amp;referenceId=hqyz5wprvmsss5YGPm8ssssstuG-378509" onclick="return goOtherCR(this, 'a=pwl_nop.more&amp;r=1&amp;i=pwl_nopmore&amp;u='+urlencode(this.href));" target="_blank">
#           더보기<i class="icon_arrow sp_nad"></i></a>
# </div>
# </div>
# </div>
# <section class="sc_new sp_nnews _prs_nws_all"> <div class="api_subject_bx"> <div class="api_title_area"> <h2 class="api_title">뉴스</h2> <div class="api_title_sub"> <a aria-selected="true" class="api_sub_option" href="?where=news&amp;query=%EC%9E%90%EC%9C%A8%EC%A3%BC%ED%96%89&amp;sort=0&amp;sm=tab_smr&amp;nso=so:r,p:all,a:all" onclick="return goOtherCR(this, 'a=nws_all.sortsim&amp;u='+urlencode(this.href));" role="option">관련도순</a> <a class="api_sub_option" href="?where=news&amp;query=%EC%9E%90%EC%9C%A8%EC%A3%BC%ED%96%89&amp;sort=1&amp;sm=tab_smr&amp;nso=so:dd,p:all,a:all" onclick="return goOtherCR(this, 'a=nws_all.sortdate&amp;u='+urlencode(this.href));" role="option">최신순</a> </div></div><div class="group_news"> <ul class="list_news"> <li class="bx" id="sp_nws_all1"> <div class="news_wrap api_ani_send"> <div class="news_area"> <div class="news_info"> <div class="api_save_group _keep_wrap"> <a aria-pressed="false" class="btn_save _keep_trigger" data-url="http://www.newsis.com/view/?id=NISX20220617_0001910903&amp;cID=10406&amp;pID=13100" href="#" onclick="tCR('a=nws_all*h.kep&amp;r=1&amp;i=88000127_000000000000000011252729&amp;u=javascript'); return false;" role="button"><i class="spnew ico_save">문서 저장하기</i></a> <div class="api_ly_save _keep_save_layer"> <a class="spnew_af item item_save _keep_save" data-cr-off="a=nws_all*h.kepoff&amp;r=1&amp;i=88000127_000000000000000011252729&amp;u=javascript" data-cr-on="a=nws_all*h.kepon&amp;r=1&amp;i=88000127_000000000000000011252729&amp;u=javascript" href="#" role="button">Keep에 저장</a> <a class="spnew_af item item_quick" href="https://keep.naver.com/" onclick="return goOtherCR(this,'a=nws_all*h.kephome&amp;r=1&amp;i=88000127_000000000000000011252729&amp;u='+urlencode(this.href));" target="_blank">Keep 바로가기</a> </div></div><div class="info_group"> <a class="info press" href="http://www.newsis.com" onclick="return goOtherCR(this, 'a=nws_all*h.prof&amp;r=1&amp;i=88000127_000000000000000011252729&amp;g=003.0011252729&amp;u='+urlencode(this.href));" target="_blank"><span class="thumb_box"><img alt="" class="thumb" height="20" onerror="this.src='...';this.className='thumb bg_default_press'" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fmimgnews.pstatic.net%2Fimage%2Fupload%2Foffice_logo%2F003%2F2019%2F02%2F19%2Flogo_003_18_20190219111719.jpg&amp;type=f54_54&amp;expire=24&amp;refresh=true" width="20"/></span>뉴시스<i class="spnew ico_pick">언론사 선정</i></a><span class="info">15시간 전</span><a class="info" href="https://n.news.naver.com/mnews/article/003/0011252729?sid=105" onclick="return goOtherCR(this, 'a=nws_all*h.nav&amp;r=1&amp;i=88000127_000000000000000011252729&amp;u='+urlencode(this.href));" target="_blank">네이버뉴스</a> </div></div><a class="news_tit" href="http://www.newsis.com/view/?id=NISX20220617_0001910903&amp;cID=10406&amp;pID=13100" onclick="return goOtherCR(this, 'a=nws_all*h.tit&amp;r=1&amp;i=88000127_000000000000000011252729&amp;g=003.0011252729&amp;u='+urlencode(this.href));" target="_blank" title="네이버가 투자한 뷰런테크놀로지, 美 자율주행 면허 취득">네이버가 투자한 뷰런테크놀로지, 美 <mark>자율주행</mark> 면허 취득</a> <div class="news_dsc"> <div class="dsc_wrap"> <a class="api_txt_lines dsc_txt_wrap" href="http://www.newsis.com/view/?id=NISX20220617_0001910903&amp;cID=10406&amp;pID=13100" onclick="return goOtherCR(this, 'a=nws_all*h.body&amp;r=1&amp;i=88000127_000000000000000011252729&amp;g=003.0011252729&amp;u='+urlencode(this.href));" target="_blank">기사내용 요약 캘리포니아서 라이다 하나로 <mark>자율주행</mark> 면허 취득한 첫 사례 LA~샌프란시스코 616㎞ <mark>자율주행</mark> 성공…최고시속 110㎞ 【서울=뉴시스】송종호 기자 = 라이다(LiDAR) <mark>자율주행</mark> 스타트업 뷰런테크놀로지가 라이다...</a> </div></div></div><a class="dsc_thumb" href="http://www.newsis.com/view/?id=NISX20220617_0001910903&amp;cID=10406&amp;pID=13100" onclick="return goOtherCR(this, 'a=nws_all*h.img&amp;r=1&amp;i=88000127_000000000000000011252729&amp;g=003.0011252729&amp;u='+urlencode(this.href));" target="_blank"><img alt="네이버가 투자한 뷰런" class="thumb api_get" height="90" onerror="this.parentNode.style.display='none';" src="htt ...
# <script> /* [AU] 인라인 스크립트 */ (function () { var CLASS_SECTION = "_sp_ntotal"; var CLASS_MARGIN = "type_margin"; var sectionEls = Array.prototype.slice.call(document.querySelectorAll("section." + CLASS_SECTION)); function matches(element, selector) { if (element.matches) return element.matches(selector); if (element.msMatchesSelector) return element.msMatchesSelector(selector); return false; } /* 연속되는 섹션 요소인지 검사한다. */ function isNextSiblingSection(sectionEl) { var targetEl = sectionEl; var targetTagName = targetEl.tagName.toLowerCase(); do { targetEl = targetEl.previousElementSibling; targetTagName = targetEl ? targetEl.tagName.toLowerCase() : ""; } while ( targetEl !== null && ( targetTagName === "script" || targetTagName === "link" ) ); if (targetEl === null) { return false; } return ( targetTagName === "section" && matches(targetEl, "." + CLASS_SECTION) ); } for (var i = 0; i < sectionEls.length; ++i) { if (isNextSiblingSection(sectionEls[i])) { sectionEls[i].classList.add(CLASS_MARGIN); } } })(); </script> <link href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_influencer_220307.css" rel="stylesheet"/><section class="sc_new sp_influencer type_bg5 _prs_ink_kic" id="_section_influencer"><div class="api_subject_bx"><div class="api_title_area"><h2 class="api_title _area_title">인플루언서<div class="api_title_inner"><a aria-pressed="false" class="api_link_help _btn_tooltip" href="#" onclick="tCR('a=ink_kic.info&amp;r=&amp;i=&amp;u=javascript')" role="button"><i class="spnew api_ico_alert">이 정보가 표시된 이유</i></a><div class="ly_api_info _layer_tooltip" style="display: none;"><p class="dsc">네이버 인플루언서로 활동하는 창작자의 콘텐츠를 검색 결과에서 제공합니다.</p><div class="btn_area"><a class="link" href="https://in.naver.com/" onclick="return goOtherCR(this,'a=ink_kic.help&amp;r=&amp;i=&amp;u='+urlencode(this.href))" target="_blank">자세히 보기</a></div><button class="btn_close _btn_tooltip" type="button"><i class="spnew ico_close">정보확인 레이어 닫기</i></button></div></div></h2><div class="api_title_sub"><a class="api_sub_link" href="
" data-lazysrc="https://search.pstatic.net/common/?src=https%3A%2F%2Fpost-phinf.pstatic.net%2FMjAyMDA3MTlfNDAg%2FMDAxNTk1MTE1MDgyOTk4.VxZZ5ZSxFYi7e-JZrTKrznO1L-zAGAMTjy6Qobr5ZHkg.QhdCFr2PwLv_EhLUuafQhbAty_40RNibkyl_bLc6Zh4g.PNG%2Fpost_1690150370063305983.png&amp;type=f76_76" height="28" onerror="this.src='...',this.className='img bg_npimg'" src="..." width="28"/></div><div class="name_area"><strong class="name">자동차 엔지니어</strong>
# <span class="num">4명</span></div></a></div><div class="flick_bx" role="presentation"><a aria-selected="false" class="option" href="?query=%EC%9E%90%EC%9C%A8%EC%A3%BC%ED%96%89&amp;where=influencer&amp;x_influencer=%7B%22filters%22%3A%7B%22majorSubject%22%3A%22143902466048000%22%2C%22minorSubject%22%3A%22%22%2C%22gender%22%3A%22%22%2C%22generation%22%3A%22%22%2C%22channel%22%3A%22%22%7D%7D" onclick="return goOtherCR(this,'a=ink_kic*f.maintheme&amp;r=&amp;i=&amp;g=K_143902466048000&amp;u='+urlencode(this.href))" role="tab"><div class="thumb"><img alt="" class="img" data-img-alias="inf-img" data-lazysrc="https://search.pstatic.net/common/?src=https%3A%2F%2Finfluencer-phinf.pstatic.net%2FMjAyMDA4MjBfMjky%2FMDAxNTk3OTE5ODAxMjI2._qKuwChoCPMbd0hFmNDBafI8iAkgoIUHVUp79Q_wutYg.qHhWLS14kEFVLdp7-rG_1EtpZp9IriPj_Fbgt_Z3tnsg.JPEG%2Fnaver_thumb.jpg&amp;type=f76_76" height="28" onerror="this.src='...',this.className='img bg_npimg'" src="..." width="28"/></div><div class="name_area"><strong class="name">자동차 딜러</strong>
# <span class="num">1명</span></div></a></div></div><div class="api_btn_page type_tag"><div class="btn_prev _scroll_prev" style="display:none;"><a class="btn" href="#" role="button"><i class="spnew ico_arr">이전</i></a></div><div class="btn_next _scroll_next" style="display:none;"><a class="btn" href="#" role="button"><i class="spnew ico_arr">다음</i></a></div></div></div></div></div><div class="challenge_wrap"><ul class="keyword_challenge_list _inf_contents"><li class="keyword_bx _item _check_visible" data-alarm-link="https://in.naver.com/prayforwish?query=%EC%9E%90%EC%9C%A8%EC%A3%BC%ED%96%89" data-alarm-name="흙맥" data-alarm-thumb="https://search.pstatic.net/common/?src=https%3A%2F%2Fhomebuilder-phinf.pstatic.net%2F%2FMjAyMjAxMDFfMTA0%2FMDAxNjQwOTcyMjg1NDk2._5QxxMaqIW2aau7WSvU15GprP1MpZsA-r7yFbPEV9Q0g.6CrYFMCRj2nLvWZCmhJ6Nvu0jK1kCxih7omJfrhfnrsg.JPEG%2F1640972285415_mercedes-benz-ge6dad9bc8_1920.jpg&amp;type=f96_96" data-containment="" data-list-index="0" data-space-id="387756483123584"><div class="keyword_box_wrap api_ani_send"><div class="user_box"><a class="user_thumb_wrap" href="https://in.naver.com/prayforwish?query=%EC%9E%90%EC%9C%A8%EC%A3%BC%ED%96%89" onclick="return goOtherCR(this,'a=ink_kic*a.profile&amp;r=1&amp;i=a0209rl4_nblog_post_222765723981&amp;u='+urlencode(this.href))" target="_blank"><i class="spinf ico_rank1">금</i><i class="spinf ico_badge_gold"></i><div class="user_thumb"><img alt="" class="img bg_npimg" data-default-class="bg_npimg" data-img-alias="inf-img" data-lazysrc="https://search.pstatic.net/common/?src=https%3A%2F%2
mlns="http://www.w3.org/2000/svg"><g fill="none" fill-rule="evenodd"><g class="fill" fill="#fff"><path d="M10 0c2.21.0 4 1.79 4 4v6c0 2.21-1.79 4-4 4H4c-2.21.0-4-1.79-4-4V4c0-2.21 1.79-4 4-4h6zM6.47 4.375H5.25v5.356h1.22v-.377c.238.271.58.447 1.035.483l.176.007c1.017.0 1.864-.842 1.939-1.96l.005-.161c0-1.143-.8-2.037-1.8-2.116l-.144-.005c-.484.0-.853.146-1.117.393l-.094.097V4.375zm.968 2.287c.566.0.987.356 1.04.934l.007.127c0 .608-.384 1.005-.928 1.055l-.12.005c-.607.0-1.047-.408-1.047-1.06.0-.609.384-1.005.928-1.055l.12-.006z" transform="translate(-1153 -1172) translate(178 230) translate(975 941) translate(0 1)"></path></g></g></svg></span>블로그 이웃 6,200+</span></span>
# <span class="bx"><span class="keyword">SUV 선호</span></span>
# <span class="bx"><span class="keyword">자동차 100대 이상 리뷰</span></span></div><div class="my_type_more"><a aria-expanded="false" aria-haspopup="true" class="btn_more _btn_expand" href="#" onclick="tCR('a=ink_kic*a.mymore&amp;r=&amp;i=&amp;u=javascript')" role="button"><svg class="ico_fold_type" fill="none" height="6" viewbox="0 0 9 6" width="9" xmlns="http://www.w3.org/2000/svg"><path class="fill" clip-rule="evenodd" d="M.22.22a.75.75.0 011.06.0l2.803 2.803L6.886.22a.75.75.0 111.061 1.06L4.083 5.144.22 1.28a.75.75.0 010-1.06z" fill="#f37a44" fill-rule="evenodd"></path></svg></a></div></div><div class="my_type_detail _area_expand" style="display: none;"><div class="dsc_bx"><div class="dsc_inner"><span class="tit">선호 차량 특징</span><span class="txt">SUV 선호</span></div><div class="dsc_inner"><span class="tit">리뷰한 자동차 수</span><span class="txt">자동차 100대 이상 리뷰</span></div></div><div class="detail_more"><a class="detail_more_link spinf_af" href="https://in.naver.com/prayforwish?search=true#COM-a4a1342a-85cc-48e2-9818-8a712b55cad2" onclick="return goOtherCR(this,'a=ink_kic*a.mydetail&amp;r=&amp;i=&amp;u='+urlencode(this.href))" target="_blank">자세히 보기</a></div></div></div></div></div><div class="detail_box"><div class="thumb_area"><div class="api_pcpg_wrap"><div class="api_flicking_wrap thumb_group_flick_wrap _scroll_target"><div class="flick_bx"><a class="thumb _cross_trigger _foryou_trigger" data-cr-gdid="a0209rl4_nblog_post_222765723981" data-foryou-gdid="a0209rl4_nblog_post_222765723981" href="https://in.naver.com/prayforwish/contents/internal/444160733751584?query=%EC%9E%90%EC%9C%A8%EC%A3%BC%ED%96%89" onclick="return goOtherCR(this,'a=ink_kic*a.blog&amp;r=1&amp;i=a0209rl4_nblog_post_222765723981&amp;u='+urlencode(this.href))" target="_blank"><i class="spinf ico_blog_b">블로그</i><img alt="" class="img bg_nimg _foryou_image_source" height="90" onerror="this.src='...',this.className='img bg_nimg'" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fmblogthumb-phinf.pstatic.net%2FMjAyMjA2MDlfNTEg%2FMDAxNjU0NzM1MjM0MjM0.gvto3KLJfcZuZGdazj9pWF6_fMI5h37vzrRFeQC51RAg.eTJuI9QxpPmpX6m2xEmyzW7o3A5r08yGqSJQTLysJQEg.PNG.prayforwish%2F%253F%2595%25A0%253F%2594%258C10.png%3Ftype%3Dw800&amp;type=o372_180" width=""/></a></div><div class="flick_bx"><a class="thumb _cross_trigger _foryou_trigger" data-cr-gdid="a0209rl4_nblog_post_222765723981" data-foryou-gdid="a0209rl4_nblog_post_222765723981" href="https://in.naver.com/prayforwish/contents/internal/444160733751584?query=%EC%9E%90%EC%9C%A8%EC%A3%BC%ED%96%89" onclick="return goOtherCR(this,'a=ink_kic*a.blog&amp;r=1&amp;i=a0209rl4_nblog_post_222765723981&amp;u='+urlencode(this.href))" target="_blank"><img alt="" class="img bg_nimg _foryou_image_source" height="90" onerror="this.src='...',this.className='img bg_nimg'" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fmblogthumb-phinf.pstatic.net%2FMjAyMjA2MDlfMTQ2%2FMDAxNjU0NzM1NjMxMzMw.wUls3LdNkbLZ2jNuyblolefNQDXvV6NpwhCbAo68Hxkg.AuAieW6ERS1sJBS4tuPxC6tfHcNQcYLJhZegLM72CQog.PNG.prayforwish%2F%25BE%25D6%25C7%25C32.png%3Ftype%3Dw800&amp;type=o372_180" width=""/></a></div><div class="flick_bx"><a class="thumb _cross_trigger _foryou_trigger" data-cr-gdid="a0209rl4_nblog_post_222765723981" data-foryou-gdid="a0209rl4_nblog_post_222765723981" href="https://in.naver.com/prayforwish/contents/internal/444160733751584?query=%EC%9E%90%EC%9C%A8%EC%A3%BC%ED%96%89" onclick="return goOtherCR(this,'a=ink_kic*a.blog&amp;r=1&amp;i=a0209rl4_nblog_post_222765723981&amp;u='+urlencode(this.href))" target="_blank"><img alt="" class="img bg_nimg _foryou_image_source" height="90" onerror="this.src='...',this.className='img bg_nimg'" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fmblogthumb-phinf.pstatic.net%2FMjAyMjA2MDlfMTE4%2FMDAxNjU0NzM1NjMxMzU5.Fmoj29gvcM5DVBWkj59KnKsn5ECdvQnwQBQ6lh1-uL8g.os1BRksXBZ3oVrGtXtgUnDtEWDHxsUGU-S7zIKFz9WMg.PNG.prayforwish%2F%25BE%25D6%25C7%25C31.png%3Ftype%3Dw800&amp;type=o372_180" width=""/></a></div><div class="flick_bx"><a clas ...
# ...
#     var _elAdIndLayerBz = null;
#     var _elAdIndLayerTimeBz;
#     var _elDscNcautionBz = null;
#
#     function adInfoShowBz(el) {
#       if (_elAdIndLayerBz) {
#         adInfoHideBz();
#         return false;
#       } else {
#         if (!_elDscNcautionBz) {
#           _elDscNcautionBz = $Element(el).parent();
#         }
#         _elDscNcautionBz._element.style.zIndex = 121;
#         _elAdIndLayerBz = $Element(el).next();
#         _elAdIndLayerBz.show();
#         _elAdIndLayerTimeBz = (new Date()).getTime();
#         return true;
#       }
#     }
#
#     function adInfoHideBz() {
#       if (_elAdIndLayerBz) {
#         if (_elDscNcautionBz) {
#           _elDscNcautionBz._element.style.zIndex = 0;
#         }
#         _elAdIndLayerBz.hide();
#         _elAdIndLayerBz = null;
#       }
#     }
#
#     function adInfoHideClickEventHandlerBz(e) {
#       if (_elAdIndLayerTimeBz + 200 < (new Date()).getTime()) adInfoHideBz();
#     }
#
#     document.body[window.addEventListener ? 'addEventListener' : 'attachEvent'](window.addEventListener ? "click" : "onclick", adInfoHideClickEventHandlerBz, false);
#   </script>
# <div class="ad_section section _bz_section bg_type_v2">
# <div class="section_head"><h2>비즈사이트</h2>
# <div class="dsc_ncaution">
# <span><em class="dsc_ncaution_quotation">‘</em>
# <strong class="dsc_ncaution_keyword">자율주행</strong>
# <em class="dsc_ncaution_quotation">’</em>
# </span>
# <span class="dsc_ncaution_text">관련 광고입니다.</span>
# <a class="ico_ad_dsc" href="javascript:void(0);" onclick="if(adInfoShowBz(this)) goOtherCR(this, 'a=biz_nop.adset&amp;r=0&amp;i=biz_nopadset&amp;u='+urlencode(this.href));" title="이 광고가 표시된 이유">이 광고가 표시된 이유</a>
# <div class="ly_ad_dsc" onclick="adInfoHideBz();" style="display:none">
# <p>광고 노출기준은 검색어에 대한 연관성과 광고주의 입찰가입니다.</p>
# <button class="bt_ad_clse" title="안내 레이어 닫기" type="button">안내 레이어 닫기</button>
# </div>
# </div>
# <a class="go_register space" href="//saedu.naver.com/adbiz/searchad/intro.nhn" onclick="return goOtherCR(this, 'a=biz_nop.registration&amp;r=0&amp;i=biz_nopregistration&amp;u='+urlencode(this.href));" target="_blank">등록 안내</a>
# </div>
# <div class="nad_area" id="biz_site_body" impression-event-url="https://event.impression-neo.naver.com/api/v1/events/naver_search/impression?x=nGwvBQHmIzzjb7ZK-xITNxWkykRMW_...">
# <ul class="lst_type">
# <li class="lst" num="0" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="inner">
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=l7l4ErQRzp1BuUAlAzsJUv///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=biz_nop.tit&amp;r=1&amp;i=nad-a001-01-000000152157294&amp;d=' + urlencode('http://www.tmon.co.kr') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <div class="lnk_tit">티몬 자율주행</div>
# </a>
# <div class="url_area">
# <span class="ico_ad_mark">광고</span>
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=l7l4ErQRzp1BuUAlAzsJUv///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=biz_nop.url&amp;r=1&amp;i=nad-a001-01-000000152157294&amp;d='+urlencode('http://www.tmon.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">www.tmon.co.kr</a>
# </div>
# <div class="ad_dsc"><p class="ad_dsc_inner">
# <strong class="hl">자율주행</strong>, 강력한혜택! 기본 할인가에 추가할인+상시 카드할인+쇼핑쿠폰할인까지!
#
#             </p></div>
# </div>
# </li>
# <li class="lst" num="1" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="inner">
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=Pn9OEJvDy4GTvY0Lmy0GY////w==...&amp;p=0" onclick="return goOtherCR(this, 'a=biz_nop.tit&amp;r=2&amp;i=nad-a001-01-000000119957297&amp;d=' + urlencode('http://www.data-hub.ai') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <div class="lnk_tit">데이터바우처, 인피닉</div>
# </a>
# <div class="url_area">
# <span class="ico_ad_mark">광고</span>
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=Pn9OEJvDy4GTvY0Lmy0GY////w==...&amp;p=1" onclick="return goOtherCR(this, 'a=biz_nop.url&amp;r=2&amp;i=nad-a001-01-000000119957297&amp;d='+urlencode('http://www.data-hub.ai')+'&amp;u='+urlencode(this.href));" target="_blank">www.data-hub.ai</a>
# </div>
# <div class="ad_dsc"><p class="ad_dsc_inner">
#               데이터바우처지원사업, 인피닉과 함께 7,000만원 지원 받으세요!
#
#             </p></div>
# </div>
# </li>
# <li class="lst" num="2" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="inner">
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=L5wJWzO3eaQGqPqGs3vUTP///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=biz_nop.tit&amp;r=3&amp;i=nad-a001-01-000000172441969&amp;d=' + urlencode('http://www.vector.com') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <div class="lnk_tit">벡터코리아 I ADAS</div>
# </a>
# <div class="url_area">
# <span class="ico_ad_mark">광고</span>
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=L5wJWzO3eaQGqPqGs3vUTP///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=biz_nop.url&amp;r=3&amp;i=nad-a001-01-000000172441969&amp;d='+urlencode('http://www.vector.com')+'&amp;u='+urlencode(this.href));" target="_blank">www.vector.com</a>
# </div>
# <div class="ad_dsc"><p class="ad_dsc_inner">
# <strong class="hl">자율주행</strong> 및 첨단 운전자 보조 시스템(ADAS)을 위한 벡터의 솔루션
#
#             </p></div>
# </div>
# </li>
# <li class="lst" num="3" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="inner">
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=xD9He2PvzGL2QL1Z8dTQYv///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=biz_nop.tit&amp;r=4&amp;i=nad-a001-01-000000140612208&amp;d=' + urlencode('http://www.linak.kr/') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <div class="lnk_tit">물류용 전동 리프트</div>
# </a>
# <div class="url_area">
# <span class="ico_ad_mark">광고</span>
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=xD9He2PvzGL2QL1Z8dTQYv///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=biz_nop.url&amp;r=4&amp;i=nad-a001-01-000000140612208&amp;d='+urlencode('http://www.linak.kr/')+'&amp;u='+urlencode(this.href));" target="_blank">www.linak.kr/</a>
# </div>
# <div class="ad_dsc"><p class="ad_dsc_inner">
#               AGV 원격 모니터링, 원격 제어가 가능한 물류 자동화용 지능형 전동 솔루션
#
#             </p></div>
# </div>
# </li>
# <li class="lst" num="4" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="inner">
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=dTHc94hJmEp2QhMCTaAHt////w==...&amp;p=0" onclick="return goOtherCR(this, 'a=biz_nop.tit&amp;r=5&amp;i=nad-a001-01-000000186406407&amp;d=' + urlencode('https://www.lotteon.com') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <div class="lnk_tit">자율주행, 롯데ON</div>
# </a>
# <div class="url_area">
# <span class="ico_ad_mark">광고</span>
# <span class="ico_area">
# <span class="ico">
# <span alt="네이버페이" class="sp_nad ico_npay" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" tabindex="0">네이버페이</span>
# <a class="ly_ad _tooltip" href="//pay.naver.com/about?frm=sa" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onclick="return goOtherCR(this, 'a=biz_nop.checkout&amp;r=5&amp;i=nad-a001-01-000000186406407&amp;u='+urlencode(this.href));" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" style="display:none" target="_blank">
# <span class="ly_box">
# <p>네이버 아이디 하나로 간편구매</p>
# <p class="ly_ad_go"><strong>Naver Pay</strong> 서비스 보기<span class="sp_nad bu"></span></p>
# </span>
# </a>
# </span>
# </span>
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=dTHc94hJmEp2QhMCTaAHt////w==...&amp;p=1" onclick="return goOtherCR(this, 'a=biz_nop.url&amp;r=5&amp;i=nad-a001-01-000000186406407&amp;d='+urlencode('https://www.lotteon.com')+'&amp;u='+urlencode(this.href));" target="_blank">www.lotteon.com</a>
# </div>
# <div class="ad_dsc"><p class="ad_dsc_inner">
#               카드7% 중복할인+2천원&amp;4천원쿠폰+네이버페이 추가적립+첫구매 1만원 할인 롯데온
#
#             </p></div>
# </div>
# </li>
# </ul>
# <div class="section_more">
# <a class="go_site" href="https://ad.search.naver.com/search.naver?where=ad&amp;query=%EC%9E%90%EC%9C%A8%EC%A3%BC%ED%96%89&amp;referenceId=hqyz5wprvmsss5YGPm8ssssstuG-378509" onclick="return goOtherCR(this, 'a=biz_nop.more&amp;r=1&amp;i=bizmore&amp;u='+urlencode(this.href));" target="_blank">
#           더보기<i class="icon_arrow sp_nad"></i></a>
# </div>
# </div>
# </div>
# <div class="api_sc_page_wrap"> <div class="sc_page"> <a aria-disabled="true" class="btn_prev" role="button"><i class="spnew ico_page_arr">이전</i></a> <div class="sc_page_inner"> <a aria-pressed="true" class="btn" href="?query=%EC%9E%90%EC%9C%A8%EC%A3%BC%ED%96%89&amp;sm=tab_pge&amp;where=nexearch" onclick="return goOtherCR(this, 'a=pag.pag&amp;r=1&amp;i=&amp;u='+urlencode(this.href ? this.href : location.href))" role="button">1</a> <a aria-pressed="false" class="btn" href="?display=15&amp;f=&amp;filetype=0&amp;page=2&amp;query=%EC%9E%90%EC%9C%A8%EC%A3%BC%ED%96%89&amp;research_url=&amp;sm=tab_pge&amp;start=1&amp;where=web" onclick="return goOtherCR(this, 'a=pag.pag&amp;r=2&amp;i=&amp;u='+urlencode(this.href ? this.href : location.href))" role="button">2</a> <a aria-pressed="false" class="btn" href="?display=15&amp;f=&amp;filetype=0&amp;page=3&amp;query=%EC%9E%90%EC%9C%A8%EC%A3%BC%ED%96%89&amp;research_url=&amp;sm=tab_pge&amp;start=16&amp;where=web" onclick="return goOtherCR(this, 'a=pag.pag&amp;r=3&amp;i=&amp;u='+urlencode(this.href ? this.href : location.href))" role="button">3</a> <a aria-pressed="false" class="btn" href="?display=15&amp;f=&amp;filetype=0&amp;page=4&amp;query=%EC%9E%90%EC%9C%A8%EC%A3%BC%ED%96%89&amp;research_url=&amp;sm=tab_pge&amp;start=31&amp;where=web" onclick="return goOtherCR(this, 'a=pag.pag&amp;r=4&amp;i=&amp;u='+urlencode(this.href ? this.href : location.href))" role="button">4</a> <a aria-pressed="false" class="btn" href="?display=15&amp;f=&amp;filetype=0&amp;page=5&amp;query=%EC%9E%90%EC%9C%A8%EC%A3%BC%ED%96%89&amp;research_url=&amp;sm=tab_pge&amp;start=46&amp;where=web" onclick="return goOtherCR(this, 'a=pag.pag&amp;r=5&amp;i=&amp;u='+urlencode(this.href ? this.href : location.href))" role="button">5</a> <a aria-pressed="false" class="btn" href="?display=15&amp;f=&amp;filetype=0&amp;page=6&amp;query=%EC%9E%90%EC%9C%A8%EC%A3%BC%ED%96%89&amp;research_url=&amp;sm=tab_pge&amp;start=61&amp;where=web" onclick="return goOtherCR(this, 'a=pag.pag&amp;r=6&amp;i=&amp;u='+urlencode(this.href ? this.href : location.href))" role="button">6</a> <a aria-pressed="false" class="btn" href="?display=15&amp;f=&amp;filetype=0&amp;page=7&amp;query=%EC%9E%90%EC%9C%A8%EC%A3%BC%ED%96%89&amp;research_url=&amp;sm=tab_pge&amp;start=76&amp;where=web" onclick="return goOtherCR(this, 'a=pag.pag&amp;r=7&amp;i=&amp;u='+urlencode(this.href ? this.href : location.href))" role="button">7</a> <a aria-pressed="false" class="btn" href="?display=15&amp;f=&amp;filetype=0&amp;page=8&amp;query=%EC%9E%90%EC%9C%A8%EC%A3%BC%ED%96%89&amp;research_url=&amp;sm=tab_pge&amp;start=91&amp;where=web" onclick="return goOtherCR(this, 'a=pag.pag&amp;r=8&amp;i=&amp;u='+urlencode(this.href ? this.href : location.href))" role="button">8</a> <a aria-pressed="false" class="btn" href="?display=15&amp;f=&amp;filetype=0&amp;page=9&amp;query=%EC%9E%90%EC%9C%A8%EC%A3%BC%ED%96%89&amp;research_url=&amp;sm=tab_pge&amp;start=106&amp;where=web" onclick="return goOtherCR(this, 'a=pag.pag&amp;r=9&amp;i=&amp;u='+urlencode(this.href ? this.href : location.href))" role="button">9</a> <a aria-pressed="false" class="btn" href="?display=15&amp;f=&amp;filetype=0&amp;page=10&amp;query=%EC%9E%90%EC%9C%A8%EC%A3%BC%ED%96%89&amp;research_url=&amp;sm=tab_pge&amp;start=121&amp;where=web" onclick="return goOtherCR(this, 'a=pag.pag&amp;r=10&amp;i=&amp;u='+urlencode(this.href ? this.href : location.href))" role="button">10</a> </div> <a aria-disabled="false" class="btn_next" href="?display=15&amp;f=&amp;filetype=0&amp;page=11&amp;query=%EC%9E%90%EC%9C%A8%EC%A3%BC%ED%96%89&amp;research_url=&amp;sm=tab_pge&amp;start=1&amp;where=web" onclick="return goOtherCR(this, 'a=pag.pag&amp;r=11&amp;i=&amp;u='+urlencode(this.href ? this.href : location.href))" role="button"><i class="spnew ico_page_arr">다음</i></a> </div> </div> <section class="sc_new sp_nkeyword" id="nx_footer_related_keywords"> <div class="api_subject_bx _related_box"> <div class="api_title_area"> <h2 class="api_title">연관 검색어<a class="a ...

# %%
# 원하는 정보를 담을 변수 생성(딕셔너리) : key 번호, value 뉴스기사정보
news_dict = {}
idx = 0 # 현재 뉴스 번호 
cur_page =1 # 네이버 뉴스 웹 페이지

# %%
print()
print('크롤링 중...')

while idx < news_num:
### 네이버 뉴스 웹페이지 구성이 바뀌어 태그명, class 속성 값 등을 수정함(20210126) ###
    
    table = soup.find_all('ul',{'class' : 'list_news'})
    li_list = table.find('li', {'id': re.compile('*.*')})
    area_list = [li.find('div', {'class' : 'news_area'}) for li in li_list]
    a_list = [area.find('a', {'class' : 'news_tit'}) for area in area_list]
    
    for n in a_list[:min(len(a_list), news_num-idx)]:
        news_dict[idx] = {'title' : n.get('title'),
                          'url' : n.get('href') }
        idx += 1

    cur_page += 1
    
    pages = soup.find('div', {'class' : 'sc_page_inner'})
    next_page_url = [p for p in pages.find_all('a') if p.text == str(cur_page)][0].get('href')
    
    req = requests.get('https://search.naver.com/search.naver' + next_page_url)
    soup = BeautifulSoup(req.text, 'html.parser')
# Out:
# 크롤링 중...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/3q/y966c1fj3lndmps8kk3plpy40000gn/T/ipykernel_77561/2549776614.py in <module>
#       6
#       7     table = soup.find_all('ul',{'class' : 'list_news'})
# ----> 8     li_list = table.find('li', {'id': re.compile('*.*')})
#       9     area_list = [li.find('div', {'class' : 'news_area'}) for li in li_list]
#      10     a_list = [area.find('a', {'class' : 'news_tit'}) for area in area_list]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/bs4/element.py in __getattr__(self, key)
#    2287     def __getattr__(self, key):
#    2288         """Raise a helpful exception to explain a common code fix."""
# -> 2289         raise AttributeError(
#    2290             "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2291         )
#
# AttributeError: ResultSet object has no attribute 'find'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?

# %%
! pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /Users/minjaering/opt/anaconda3/lib/python3.9/site-packages (3.0.9)
# Requirement already satisfied: et-xmlfile in /Users/minjaering/opt/anaconda3/lib/python3.9/site-packages (from openpyxl) (1.1.0)

# %%
print('크롤링 완료')
print('데이터프레임 변환')
news_df = DataFrame(news_dict).T

folder_path = os.getcwd()
csv_file_name = '네이버뉴스_{}_{}.csv'.format(query, date)

news_df.to_csv(csv_file_name)

print('엑셀 저장 완료 | 경로 : {}\\{}'.format(folder_path, csv_file_name))
# Out:
# 크롤링 완료
# 데이터프레임 변환
# 엑셀 저장 완료 | 경로 : /Users/minjaering/Desktop/2차project\네이버뉴스___2_0_2_2_-_0_6_-_1_7_ _1_7_시_0_5_분.csv
